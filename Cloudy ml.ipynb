# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('/home/vinod/Downloads/Python-3.10.3/data.csv')

# %%
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.drop(["Engine Fuel Type", "Market Category", "Vehicle Style", "Popularity", "Number of Doors",
"Vehicle Size"],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#       Driven_Wheels  highway MPG  city mpg   MSRP
# 0  rear wheel drive           26        19  46135
# 1  rear wheel drive           28        19  40650
# 2  rear wheel drive           28        20  36350
# 3  rear wheel drive           28        18  29450
# 4  rear wheel drive           28        18  34500

# %%
rename_cols = df.rename(columns={"Engine HP":"HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Tr","Driven_Wheels": "Drive_Mode","highway MPG": "MPG_H", "city mpg": "MPG_C" })

# %%
df1=rename_cols

# %%
df1.head(5)
# Out:
#   Make       Model  Year     HP  Cylinders      Tr        Drive_Mode  MPG_H  \
# 0  BMW  1 Series M  2011  335.0        6.0  MANUAL  rear wheel drive     26
# 1  BMW    1 Series  2011  300.0        6.0  MANUAL  rear wheel drive     28
# 2  BMW    1 Series  2011  300.0        6.0  MANUAL  rear wheel drive     28
# 3  BMW    1 Series  2011  230.0        6.0  MANUAL  rear wheel drive     28
# 4  BMW    1 Series  2011  230.0        6.0  MANUAL  rear wheel drive     28
#
#    MPG_C   MSRP
# 0     19  46135
# 1     19  40650
# 2     20  36350
# 3     18  29450
# 4     18  34500

# %%
df1.count()
# Out:
# Make          10827
# Model         10827
# Year          10827
# HP            10827
# Cylinders     10827
# Tr            10827
# Drive Mode    10827
# MPG_H         10827
# MPG_C         10827
# MSRP          10827
# dtype: int64

# %%
df1[df1.duplicated()].sum()
# Out:
# Make          0.0
# Model         0.0
# Year          0.0
# HP            0.0
# Cylinders     0.0
# Tr            0.0
# Drive Mode    0.0
# MPG_H         0.0
# MPG_C         0.0
# MSRP          0.0
# dtype: float64

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.head(5)
# Out:
#   Make       Model  Year     HP  Cylinders      Tr        Drive Mode  MPG_H  \
# 0  BMW  1 Series M  2011  335.0        6.0  MANUAL  rear wheel drive     26
# 1  BMW    1 Series  2011  300.0        6.0  MANUAL  rear wheel drive     28
# 2  BMW    1 Series  2011  300.0        6.0  MANUAL  rear wheel drive     28
# 3  BMW    1 Series  2011  230.0        6.0  MANUAL  rear wheel drive     28
# 4  BMW    1 Series  2011  230.0        6.0  MANUAL  rear wheel drive     28
#
#    MPG_C   MSRP
# 0     19  46135
# 1     19  40650
# 2     20  36350
# 3     18  29450
# 4     18  34500

# %% [markdown]
#  df1.count()

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# highway MPG          0
# city mpg             0
# MSRP                 0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.head(5)
# Out:
#   Make       Model  Year     HP  Cylinders      Tr        Drive Mode  MPG_H  \
# 0  BMW  1 Series M  2011  335.0        6.0  MANUAL  rear wheel drive     26
# 1  BMW    1 Series  2011  300.0        6.0  MANUAL  rear wheel drive     28
# 2  BMW    1 Series  2011  300.0        6.0  MANUAL  rear wheel drive     28
# 3  BMW    1 Series  2011  230.0        6.0  MANUAL  rear wheel drive     28
# 4  BMW    1 Series  2011  230.0        6.0  MANUAL  rear wheel drive     28
#
#    MPG_C   MSRP
# 0     19  46135
# 1     19  40650
# 2     20  36350
# 3     18  29450
# 4     18  34500

# %%
df1.isnull().sum()
# Out:
# Make          0
# Model         0
# Year          0
# HP            0
# Cylinders     0
# Tr            0
# Drive Mode    0
# MPG_H         0
# MPG_C         0
# MSRP          0
# dtype: int64

# %%
df1.describe()
# Out:
#                Year            HP     Cylinders         MPG_H         MPG_C  \
# count  10827.000000  10827.000000  10827.000000  10827.000000  10827.000000
# mean    2010.896370    254.553062      5.691604     26.308119     19.327607
# std        7.029534    109.841537      1.768551      7.504652      6.643567
# min     1990.000000     55.000000      0.000000     12.000000      7.000000
# 25%     2007.000000    173.000000      4.000000     22.000000     16.000000
# 50%     2015.000000    240.000000      6.000000     25.000000     18.000000
# 75%     2016.000000    303.000000      6.000000     30.000000     22.000000
# max     2017.000000   1001.000000     16.000000    354.000000    137.000000
#
#                MSRP
# count  1.082700e+04
# mean   4.249325e+04
# std    6.229451e+04
# min    2.000000e+03
# 25%    2.197250e+04
# 50%    3.084500e+04
# 75%    4.330000e+04
# max    2.065902e+06

# %%
sns.boxplot(x=df1['MSRP'])
# Out:
# <AxesSubplot:xlabel='MSRP'>

# %%
sns.boxplot(x=df1['HP'])
# Out:
# <AxesSubplot:xlabel='HP'>

# %%
sns.boxplot(x=df1['Cylinders'])
# Out:
# <AxesSubplot:xlabel='Cylinders'>

# %%
df1.head(5)
# Out:
#   Make       Model  Year     HP  Cylinders      Tr        Drive Mode  MPG_H  \
# 0  BMW  1 Series M  2011  335.0        6.0  MANUAL  rear wheel drive     26
# 1  BMW    1 Series  2011  300.0        6.0  MANUAL  rear wheel drive     28
# 2  BMW    1 Series  2011  300.0        6.0  MANUAL  rear wheel drive     28
# 3  BMW    1 Series  2011  230.0        6.0  MANUAL  rear wheel drive     28
# 4  BMW    1 Series  2011  230.0        6.0  MANUAL  rear wheel drive     28
#
#    MPG_C   MSRP
# 0     19  46135
# 1     19  40650
# 2     20  36350
# 3     18  29450
# 4     18  34500

# %%
df1.columns
# Out:
# Index(['Make', 'Model', 'Year', 'HP', 'Cylinders', 'Tr', 'Drive Mode', 'MPG_H',
#        'MPG_C', 'MSRP'],
#       dtype='object')

# %%
l=df1.loc[:,["Year","Cylinders","HP","MPG_H","MPG_C","MSRP"]]

# %%
l
# Out:
#        Year  Cylinders     HP  MPG_H  MPG_C   MSRP
# 0      2011        6.0  335.0     26     19  46135
# 1      2011        6.0  300.0     28     19  40650
# 2      2011        6.0  300.0     28     20  36350
# 3      2011        6.0  230.0     28     18  29450
# 4      2011        6.0  230.0     28     18  34500
# ...     ...        ...    ...    ...    ...    ...
# 11909  2012        6.0  300.0     23     16  46120
# 11910  2012        6.0  300.0     23     16  56670
# 11911  2012        6.0  300.0     23     16  50620
# 11912  2013        6.0  300.0     23     16  50920
# 11913  2006        6.0  221.0     26     17  28995
#
# [10827 rows x 6 columns]

# %%
Q1=df.MSRP.quantile(.25)
Q3=df.MSRP.quantile(.75)
IQR=Q3-Q1

# %%
IQR
# Out:
# 21327.5

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR

# %%
lower_limit,upper_limit
# Out:
# (-10018.75, 75291.25)

# %%
df2=df[(df1.MSRP<lower_limit)|(df1.MSRP>upper_limit)]

# %%
df2
# Out:
#            Make Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 294     Ferrari   360  2002      400.0               8.0            MANUAL
# 295     Ferrari   360  2002      400.0               8.0            MANUAL
# 296     Ferrari   360  2002      400.0               8.0  AUTOMATED_MANUAL
# 297     Ferrari   360  2002      400.0               8.0  AUTOMATED_MANUAL
# 298     Ferrari   360  2003      400.0               8.0            MANUAL
# ...         ...   ...   ...        ...               ...               ...
# 11736  Cadillac   XLR  2008      320.0               8.0         AUTOMATIC
# 11737  Cadillac   XLR  2009      320.0               8.0         AUTOMATIC
# 11903       BMW    Z8  2001      394.0               8.0            MANUAL
# 11904       BMW    Z8  2002      394.0               8.0            MANUAL
# 11905       BMW    Z8  2003      394.0               8.0            MANUAL
#
#           Driven_Wheels  highway MPG  city mpg    MSRP
# 294    rear wheel drive           15        10  160829
# 295    rear wheel drive           15        10  140615
# 296    rear wheel drive           15        10  150694
# 297    rear wheel drive           15        10  170829
# 298    rear wheel drive           15        10  165986
# ...                 ...          ...       ...     ...
# 11736  rear wheel drive           24        15   85650
# 11737  rear wheel drive           24        15   86215
# 11903  rear wheel drive           19        12  128000
# 11904  rear wheel drive           19        12  130000
# 11905  rear wheel drive           19        12  131500
#
# [936 rows x 10 columns]

# %%
from scipy import stats

# %%
z_scores=np.abs(stats.zscore(l))

# %%
z_scores
# Out:
#            Year  Cylinders        HP     MPG_H     MPG_C      MSRP
# 0      0.014743   0.174386  0.732425  0.041059  0.049314  0.058463
# 1      0.014743   0.174386  0.413769  0.225455  0.049314  0.029591
# 2      0.014743   0.174386  0.413769  0.225455  0.101214  0.098621
# 3      0.014743   0.174386  0.223542  0.225455  0.199843  0.209390
# 4      0.014743   0.174386  0.223542  0.225455  0.199843  0.128320
# ...         ...        ...       ...       ...       ...       ...
# 11909  0.157006   0.174386  0.413769  0.440829  0.500900  0.058222
# 11910  0.157006   0.174386  0.413769  0.440829  0.500900  0.227587
# 11911  0.157006   0.174386  0.413769  0.440829  0.500900  0.130463
# 11912  0.299270   0.174386  0.413769  0.440829  0.500900  0.135279
# 11913  0.696575   0.174386  0.305482  0.041059  0.350371  0.216695
#
# [10827 rows x 6 columns]

# %%
zscores=stats.zscore(l)

# %%
zscores
# Out:
#            Year  Cylinders        HP     MPG_H     MPG_C      MSRP
# 0      0.014743   0.174386  0.732425 -0.041059 -0.049314  0.058463
# 1      0.014743   0.174386  0.413769  0.225455 -0.049314 -0.029591
# 2      0.014743   0.174386  0.413769  0.225455  0.101214 -0.098621
# 3      0.014743   0.174386 -0.223542  0.225455 -0.199843 -0.209390
# 4      0.014743   0.174386 -0.223542  0.225455 -0.199843 -0.128320
# ...         ...        ...       ...       ...       ...       ...
# 11909  0.157006   0.174386  0.413769 -0.440829 -0.500900  0.058222
# 11910  0.157006   0.174386  0.413769 -0.440829 -0.500900  0.227587
# 11911  0.157006   0.174386  0.413769 -0.440829 -0.500900  0.130463
# 11912  0.299270   0.174386  0.413769 -0.440829 -0.500900  0.135279
# 11913 -0.696575   0.174386 -0.305482 -0.041059 -0.350371 -0.216695
#
# [10827 rows x 6 columns]

# %%
df.head(5)
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#       Driven_Wheels  highway MPG  city mpg   MSRP
# 0  rear wheel drive           26        19  46135
# 1  rear wheel drive           28        19  40650
# 2  rear wheel drive           28        20  36350
# 3  rear wheel drive           28        18  29450
# 4  rear wheel drive           28        18  34500

# %%
for i in df.columns:
    print("the car %s brand in column" %i)
df['Make'].value_counts()
# Out:
# the car Make brand in column
# the car Model brand in column
# the car Year brand in column
# the car Engine HP brand in column
# the car Engine Cylinders brand in column
# the car Transmission Type brand in column
# the car Driven_Wheels brand in column
# the car highway MPG brand in column
# the car city mpg brand in column
# the car MSRP brand in column
# Chevrolet        1043
# Ford              798
# Toyota            651
# Volkswagen        563
# Nissan            540
# Dodge             513
# GMC               475
# Honda             429
# Cadillac          396
# Mazda             392
# Mercedes-Benz     340
# Suzuki            338
# Infiniti          326
# BMW               324
# Audi              320
# Hyundai           254
# Acura             246
# Volvo             241
# Subaru            229
# Kia               219
# Mitsubishi        202
# Lexus             201
# Chrysler          185
# Buick             184
# Pontiac           163
# Lincoln           152
# Porsche           134
# Land Rover        126
# Oldsmobile        111
# Saab              101
# Aston Martin       91
# Bentley            74
# Ferrari            69
# Plymouth           62
# Scion              60
# FIAT               58
# Maserati           55
# Lamborghini        52
# Rolls-Royce        31
# Lotus              28
# HUMMER             17
# Maybach            16
# McLaren             5
# Alfa Romeo          5
# Genesis             3
# Bugatti             3
# Spyker              2
# Name: Make, dtype: int64

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders',
#        'Transmission Type', 'Driven_Wheels', 'highway MPG', 'city mpg',
#        'MSRP'],
#       dtype='object')

# %%
sns.distplot(df1.HP,hist=True,color='r')
# Out:
# /home/vinod/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HP', ylabel='Density'>

# %%
l
# Out:
#        Year  Cylinders     HP  MPG_H  MPG_C   MSRP
# 0      2011        6.0  335.0     26     19  46135
# 1      2011        6.0  300.0     28     19  40650
# 2      2011        6.0  300.0     28     20  36350
# 3      2011        6.0  230.0     28     18  29450
# 4      2011        6.0  230.0     28     18  34500
# ...     ...        ...    ...    ...    ...    ...
# 11909  2012        6.0  300.0     23     16  46120
# 11910  2012        6.0  300.0     23     16  56670
# 11911  2012        6.0  300.0     23     16  50620
# 11912  2013        6.0  300.0     23     16  50920
# 11913  2006        6.0  221.0     26     17  28995
#
# [10827 rows x 6 columns]

# %%
c=0
plt.figure(figsize=(15,10))
for i in l:
    l.plot(xlabel='Density',ylabel='Year')
    l.plot(xlabel='Density',ylabel='HP')
    l.plot(xlabel='Density',ylabel='MPG_H')
    l.plot(xlabel='Density',ylabel='MPG_C')
    l.plot(xlabel='Density',ylabel='MSRP')
plt.show()
# Out:
# /home/vinod/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:345: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
plt.figure(figsize = (12,8))
df1.plot(x='Make',kind='bar',ax=None)


plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
df1.head(2)
# Out:
#   Make       Model  Year     HP  Cylinders      Tr        Drive_Mode  MPG_H  \
# 0  BMW  1 Series M  2011  335.0        6.0  MANUAL  rear wheel drive     26
# 1  BMW    1 Series  2011  300.0        6.0  MANUAL  rear wheel drive     28
#
#    MPG_C   MSRP
# 0     19  46135
# 1     19  40650

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Tr',data=df1,hue='Drive_Mode')
# Out:
# <AxesSubplot:xlabel='Tr', ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(10,6))
x='HP'
y='MSRP'
plt.scatter(x,y,data=df1)

# %%
sns.jointplot(x='MPG_H',y='MPG_C',data=df1)

# %%
from numpy import median
sns.barplot(x='Cylinders',y='MSRP',data=df1,estimator=median)
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='MSRP'>

# %%
sns.barplot(x='MSRP',y='Tr',data=df1)
# Out:
# <AxesSubplot:xlabel='MSRP', ylabel='Tr'>

# %%
plt.figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
sns.barplot(x='MSRP',y='Tr',hue='Drive_Mode',data=df1)
# Out:
# <AxesSubplot:xlabel='MSRP', ylabel='Tr'>

# %%
sns.pairplot(data=df)

# %%
cor=df1.corr()

# %%
cor
# Out:
#                Year        HP  Cylinders     MPG_H     MPG_C      MSRP
# Year       1.000000  0.314971  -0.050598  0.284237  0.234135  0.196789
# HP         0.314971  1.000000   0.788007 -0.420281 -0.473551  0.659835
# Cylinders -0.050598  0.788007   1.000000 -0.611576 -0.632407  0.554740
# MPG_H      0.284237 -0.420281  -0.611576  1.000000  0.841229 -0.209150
# MPG_C      0.234135 -0.473551  -0.632407  0.841229  1.000000 -0.234050
# MSRP       0.196789  0.659835   0.554740 -0.209150 -0.234050  1.000000

# %%
#set cmap = 'BrBG', annot = True - to get the same graph as shown below 
# set size of graph = (12,8)
plt.figure(figsize=(12,8))
sns.heatmap(cor,annot=True,cmap='BrBG')
# Out:
# <AxesSubplot:>
